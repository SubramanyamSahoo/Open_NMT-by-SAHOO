# %% [markdown]
# <a href="https://colab.research.google.com/github/SubramanyamSahoo/Open_NMT-by-SAHOO/blob/main/Subramanyam_Sahoo_OpenNMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to run OpenNMT on google colab:**
# - Notebook settings
# - OpenNMT installation
# - Files prepration
# - Config file
# - Training
# - Testing a model

# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !onmt_build_vocab -config Data/config.yaml -n_sample 2500
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-12-07 05:54:31,830 INFO] Counter vocab from 2500 samples.
# [2022-12-07 05:54:31,830 INFO] Build vocab on 2500 transformed examples/corpus.
# [2022-12-07 05:54:31,904 INFO] Counters src:4994
# [2022-12-07 05:54:31,904 INFO] Counters tgt:5935
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.8/dist-packages/onmt/bin/build_vocab.py", line 200, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.8/dist-packages/onmt/bin/build_vocab.py", line 184, in build_vocab_main
#     save_counter(src_counter, opts.src_vocab)
#   File "/usr/local/lib/python3.8/dist-packages/onmt/bin/build_vocab.py", line 173, in save_counter
#     check_path(save_path, exist_ok=opts.overwrite, log=logger.warning)
#   File "/usr/local/lib/python3.8/dist-packages/onmt/utils/misc.py", line 47, in check_path
# ...

# %%
# !onmt_train -config Data/config.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# [2022-12-07 06:05:49,284 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4008
# [2022-12-07 06:05:49,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4009
# [2022-12-07 06:05:49,335 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4010
# [2022-12-07 06:05:49,363 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4011
# [2022-12-07 06:05:49,391 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4012
# [2022-12-07 06:05:49,415 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4013
# [2022-12-07 06:05:49,440 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4014
# [2022-12-07 06:05:49,469 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4015
# [2022-12-07 06:05:49,495 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4016
# [2022-12-07 06:05:49,516 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4017
# [2022-12-07 06:05:49,540 INFO] Weighted corpora loaded so far:
# ...

# %%
# !onmt_translate -model Data/run/model_step_1000.pt -src Data/src-test.txt -output Data/pred_1000.txt -gpu 0 -verbose
# Out:
# [2022-12-07 06:13:25,482 INFO]
# SENT 1: None
# PRED 1: यौन जनित रोग का उपचार करें ।
# PRED SCORE: -0.9282
#
# [2022-12-07 06:13:25,482 INFO]
# SENT 2: None
# PRED 2: आँखों के किसी भाग का प्रयोग करें ।
# PRED SCORE: -0.9904
#
# [2022-12-07 06:13:25,482 INFO]
# SENT 3: None
# PRED 3: शरीर के किसी भाग में किसी प्रकार का पता लग सकता है ।
# PRED SCORE: -1.0145
#
# [2022-12-07 06:13:25,482 INFO]
# SENT 4: None
# PRED 4: स्तन कैंसर की पहचान करने के लिए बढ़ती है ।
# PRED SCORE: -0.9182
#
# [2022-12-07 06:13:25,482 INFO]
# SENT 5: None
# PRED 5: पूरी आस्तीन के बाद आपको - प्रयोग न कर सकते हैं , पर आप अपने किसी से जाँच न ले सकते हैं ।
# PRED SCORE: -1.4162
#
# [2022-12-07 06:13:25,483 INFO]
# SENT 6: None
# PRED 6: शरीर के किसी भाग में किसी भी अंग में परेशानी हो जाता है ।
# PRED SCORE: -1.1189
#
# [2022-12-07 06:13:25,483 INFO]
# SENT 7: None
# PRED 7: हर्निया की तीव्रता पर निर्भर करता है कि कैंसर का अनुमान किया जाता है ।
# PRED SCORE: -1.1143
#
# [2022-12-07 06:13:25,483 INFO]
# SENT 8: None
# ...
